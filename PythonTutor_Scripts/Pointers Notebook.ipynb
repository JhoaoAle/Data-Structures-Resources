// %%
#include<stdio.h>

// %% [markdown]
// ## Definitions
//
// A pointer is a variable that stores the address of another variable

// %% [markdown]
// Data Types Sizes:
//
// - int - 4 bytes
//
// - char - 1 byte
//
// - float - 4 bytes

// %% [markdown]
// ## 1. Pointer Basic Usage

// %%
int a;
int *p;
p = &a; // Where &a means "Address of a"
printf("p as type int = %d \n", p); // Trying to show an address as an integer
printf("p as type p = %p \n", p); // Showing an address as its corresponding data type
printf("*p as type int = %d \n", *p); // *p - Value at the address pointed by p
// Out:
// input_line_8:5:33: warning: format specifies type 'int' but the argument has type 'int *' [-Wformat]
// printf("p as type int = %d \n", p); // Trying to show an address as an integer
//                         ~~      ^
// p as type int = -1838043096
// p as type p = 0x7f139271b028
// *p as type int = 0
// 20

// %% [markdown]
// ## 2. Proper initialization and Dereferencing

// %%
int b = 10;
p = &b; // Where &b means "Address of b"
printf("p as type p = %p \n", p); // Showing an address as its corresponding data type
printf("*p as type int = %d \n", *p); // *p - Value at the address pointed by p
printf("p as type int = %d \n", p);
printf("&b as type int = %d \n", &b);

*p = 16;
printf("*p = %d \n", *p); // *p - Value at the address pointed by p
printf("b = %d \n", b);
// Out:
// input_line_12:6:33: warning: format specifies type 'int' but the argument has type 'int *' [-Wformat]
// printf("p as type int = %d \n", p);
//                         ~~      ^
// input_line_12:7:34: warning: format specifies type 'int' but the argument has type 'int *' [-Wformat]
// printf("&b as type int = %d \n", &b);
//                          ~~      ^~
// p as type p = 0x7f139271b038
// *p as type int = 10
// p as type int = -1838043080
// &b as type int = -1838043080
// *p = 16
// b = 16

// %% [markdown]
// ## 3. Pointer Logic

// %%
printf("Value stored in p = %d \n", *p); // *p - Value at the address pointed by p
printf("Address of p = %p \n", p);
// Out:
// Value stored in p = 16
// Address of p = 0x7f139271b038

// %%
int c = 20;
*p = c;

// %% [markdown]
// ### Question
//
// Will the address stored in *p now point to where c is stored?

// %%
printf("Value stored in p = %d \n", *p); // *p - Value at the address pointed by p
printf("Address of p = %p \n", p);
// Out:
// Value stored in p = 20
// Address of p = 0x7f139271b038

// %% [markdown]
// ## 4. Syntax

// %%
int *q = &c;
int* r = &c;

// %% [markdown]
// ### Question
//
// Of the above code, which assignation will work? q? r? Neither? Both?

// %%
printf("Value stored in address pointed at by q = %d \n", *q);
printf("Value stored in address pointed at by r = %d \n", *r);

printf("Address stored in q = %p \n", q);
printf("Address stored in r = %p \n", r);
// Out:
// Value stored in address pointed at by q = 20
// Value stored in address pointed at by r = 20
// Address stored in q = 0x7f139271b03c
// Address stored in r = 0x7f139271b03c

// %% [markdown]
// ## 5. Pointer arithmetic

// %%
int d = 14;
int *w = &d;

printf("Value stored in the address pointed at by w = %d \n", *w);
printf("Arithmetic through the pointer: Adding 1 = %d \n", *w + 1); //What will this be?
printf("%d \n", w );
printf("%d \n", w + 1); //What will this be and why?

printf("%p \n", w );
printf("%p \n", w + 1); //What will this be and why?

printf ("Size of integer is %d bytes \n", (int)sizeof(int));

printf ("Value at address w + 1: %d \n", *(w+1));
// Out:
// input_line_18:6:17: warning: format specifies type 'int' but the argument has type 'int *' [-Wformat]
// printf("%d \n", w );
//         ~~      ^
// input_line_18:7:17: warning: format specifies type 'int' but the argument has type 'int *' [-Wformat]
// printf("%d \n", w + 1); //What will this be and why?
//         ~~      ^~~~~
// Value stored in the address pointed at by w = 14
// Arithmetic through the pointer: Adding 1 = 15
// -1838043056
// -1838043052
// 0x7f139271b050
// 0x7f139271b054
// Size of integer is 4 bytes
// Value at address w + 1: 0

// %% [markdown]
// ## 6. Pointers and DataTypes consideration
//
// Pointers are strongly typed. Which means a pointer to a variable has to be the same data type of the variable it is pointing to.
// int* -> int
// char* -> char
//
// - Why would this matter if the pointer always stores an address?
//
// - Why not have one generic type?
//
// Discuss.

// %%
int a0 = 1025;
int *p0 = &a0;
printf ("Size of integer is %d bytes \n", (int)sizeof(int));
printf ("Value %d at address %p (%d casted as int) \n", *p0, p0, p0);
printf ("Value %d at address %p (%d casted as int) \n", *(p0+1), p0+1, p0+1);
// Out:
// input_line_19:5:66: warning: format specifies type 'int' but the argument has type 'int *' [-Wformat]
// printf ("Value %d at address %p (%d casted as int) \n", *p0, p0, p0);
//                                  ~~                              ^~
// input_line_19:6:72: warning: format specifies type 'int' but the argument has type 'int *' [-Wformat]
// printf ("Value %d at address %p (%d casted as int) \n", *(p0+1), p0+1, p0+1);
//                                  ~~                                    ^~~~
// Size of integer is 4 bytes
// Value 1025 at address 0x7f139271b060 (-1838043040 casted as int)
// Value 0 at address 0x7f139271b064 (-1838043036 casted as int)

// %%
char *p1;

// %%
//p1 = p0;

// %%
p1 = (char*)p0;

// %%
printf ("Size of char is %d bytes \n", (int)sizeof(char));

//1025 = 00000000 00000000 00000100 00000001 
printf ("Value %d at address %p (%d casted as int) \n", *p1, p1, p1);
printf ("Value %d at address %p (%d casted as int) \n", *(p1+1), p1+1, p1+1);
// Out:
// input_line_23:4:66: warning: format specifies type 'int' but the argument has type 'char *' [-Wformat]
// printf ("Value %d at address %p (%d casted as int) \n", *p1, p1, p1);
//                                  ~~                              ^~
//                                  %s
// input_line_23:5:72: warning: format specifies type 'int' but the argument has type 'char *' [-Wformat]
// printf ("Value %d at address %p (%d casted as int) \n", *(p1+1), p1+1, p1+1);
//                                  ~~                                    ^~~~
//                                  %s
// Size of char is 1 bytes
// Value 1 at address 0x7f139271b060 (-1838043040 casted as int)
// Value 4 at address 0x7f139271b061 (-1838043039 casted as int)

// %% [markdown]
// The answer is something already showcased: Dereferencing!
// Dereference allows us to access and modify the data saved in the address to which the pointer "points".
// Each data type differs on how they store information.
//
// For example, for the above code: int a = 1025
//
//
// | byte3  | byte2  | byte1  | byte0 (Least significant byte) |
// |---|---|---|---|
// | 0x...203  | 0x...202  | 0x...201  | 0x200 |
// | 00000000  | 00000000  | 00000100  | 00000001  |
//
//
// Leftmost byte is sign byte (to indicate negative or positive integer)
// So...
//
//
// Printing p -> 0x...200
// Dereferencing (Printing *p, the value) -> Compiler looks at 4 bytes starting at 0x...200
//
// What happens when p is a char*? Discuss

// %% [markdown]
// ## 7. Generic Pointer

// %%
void *pvoid;
pvoid = p0;

// %%
printf ("Value %d at address %p (%d casted as int) \n", *pvoid, pvoid, pvoid );
// Out:
// input_line_25:2:58: warning: ISO C++ does not allow indirection on operand of type 'void *' [-Wvoid-ptr-dereference]
//  printf ("Value %d at address %p (%d casted as int) \n", *pvoid, pvoid, pvoid );
//                                                          ^~~~~~
// input_line_25:2:58: error: cannot pass expression of type 'void' to variadic function; expected type from format string was 'int'
//  printf ("Value %d at address %p (%d casted as int) \n", *pvoid, pvoid, pvoid );
//                                                          ^~~~~~
// input_line_25:2:73: warning: format specifies type 'int' but the argument has type 'void *' [-Wformat]
//  printf ("Value %d at address %p (%d casted as int) \n", *pvoid, pvoid, pvoid );
//                                   ~~                                    ^~~~~
// Interpreter Error:

// %% [markdown]
// ## 8. Pointer to pointer

// %%
int x = 5;
int *px = &x;
int **qp = &px;
int ***rq = &qp;

printf ("%d \n", *px);
printf ("%d \n", *qp); 
printf ("%d \n", **qp); 
printf ("%d \n", **rq);
printf ("%d \n", ***rq);
***rq = 10; 
printf("x = %d \n",x);
// Out:
// input_line_26:7:18: warning: format specifies type 'int' but the argument has type 'int *' [-Wformat]
// printf ("%d \n", *qp);
//          ~~      ^~~
// input_line_26:9:18: warning: format specifies type 'int' but the argument has type 'int *' [-Wformat]
// printf ("%d \n", **rq);
//          ~~      ^~~~
// 5
// -1838043008
// 5
// -1838043008
// 5
// x = 10

// %% [markdown]
// ## 9. Pointers as function arguments

// %%
void increment(int a){
    a = a + 1;
}

int var = 10;
increment(var); // a = a+1;
printf("var: %d", var);
// Out:
// var: 10

// %% [markdown]
// ### Question
//
// The idea is to increment the value of the variable through a function. But it seems to not be working. Why is it not working and how can it be implement through a void function (no return statements)?
//
// Discuss

// %%
void increment(int a){
    a = a + 1; // Local variable
}

int var = 10; //Local Variable
increment(var); // var = var + 1;
printf("var: %d", var);
// Out:
// var: 10

// %% [markdown]
// ## 10. Pointers and Arrays

// %%
int sum_of_elements(int A[]){
    int i, sum = 0;
    int size = sizeof(A)/sizeof(A[0]);
    printf("\n SOE - Size of Function A = %d, size of Function A[0] = %d \n", sizeof(A),sizeof(A[0]));
    for (i = 0; i < size; i++){
        sum += A[i];
    }
    return sum;
}

int A[] = {1, 2, 3, 4, 5};
printf("\n SOE - Size of Real A = %d, size of Real A[0] = %d \n", sizeof(A),sizeof(A[0]));
int total = sum_of_elements(A);
printf("Sum of total elements = %d \n", total);
// Out:
// input_line_30:3:22: warning: sizeof on array function parameter will return size of 'int *' instead of 'int []' [-Wsizeof-array-argument]
//     int size = sizeof(A)/sizeof(A[0]);
//                      ^
// input_line_30:1:25: note: declared here
// int sum_of_elements(int A[]){
//                         ^
// input_line_30:3:25: warning: 'sizeof (A)' will return the size of the pointer, not the array itself [-Wsizeof-pointer-div]
//     int size = sizeof(A)/sizeof(A[0]);
//                ~~~~~~~~~^
// input_line_30:4:85: warning: sizeof on array function parameter will return size of 'int *' instead of 'int []' [-Wsizeof-array-argument]
//     printf("\n SOE - Size of Function A = %d, size of Function A[0] = %d \n", sizeof(A),sizeof(A[0]));
//                                                                                     ^
// input_line_30:1:25: note: declared here
// int sum_of_elements(int A[]){
//                         ^
// input_line_30:4:79: warning: format specifies type 'int' but the argument has type 'unsigned long' [-Wformat]
//     printf("\n SOE - Size of Function A = %d, size of Function A[0] = %d \n", sizeof(A),sizeof(A[0]));
//                                           ~~                                  ^~~~~~~~~
//                                           %lu
// input_line_30:4:89: warning: format specifies type 'int' but the argument has type 'unsigned long' [-Wformat]
//     printf("\n SOE - Size of Function A = %d, size of Function A[0] = %d \n", sizeof(A),sizeof(A[0]));
//                                                                       ~~                ^~~~~~~~~~~~
//                                                                       %lu
// input_line_30:12:67: warning: format specifies type 'int' but the argument has type 'unsigned long' [-Wformat]
// printf("\n SOE - Size of Real A = %d, size of Real A[0] = %d \n", sizeof(A),sizeof(A[0]));
//                                   ~~                              ^~~~~~~~~
//                                   %lu
// input_line_30:12:77: warning: format specifies type 'int' but the argument has type 'unsigned long' [-Wformat]
// printf("\n SOE - Size of Real A = %d, size of Real A[0] = %d \n", sizeof(A),sizeof(A[0]));
//                                                           ~~                ^~~~~~~~~~~~
//                                                           %lu
//  SOE - Size of Real A = 20, size of Real A[0] = 4
//
//  SOE - Size of Function A = 8, size of Function A[0] = 4
// Sum of total elements = 3

// %% [markdown]
// ### Question
//
// Why does the above code not work as intended?
//
// Why is the size of Function A defined as 8 bytes if the size of an integer, as per size_of A[0] is 4 bytes?
//
// Discuss.
